# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Cleaning CONTENT

# %%
df_content= pd.read_csv('Anu_Content.csv')
df_content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df_content_cap=df_content['Category'].str.title() ## To capitalise the 1st letter of each words.
df_content_cap
# Out:
# 0             Studying
# 1       Healthy Eating
# 2       Healthy Eating
# 3           Technology
# 4                 Food
#             ...
# 995    Public Speaking
# 996         Technology
# 997           Veganism
# 998            Culture
# 999         Technology
# Name: Category, Length: 1000, dtype: object

# %%
concat_1= df_content[['Content ID', 'User ID', 'Type', 'URL']]
concat_1.head(5)
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type                                                URL
# 0  photo  https://socialbuzz.cdn.com/content/storage/975...
# 1  photo  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  photo  https://socialbuzz.cdn.com/content/storage/230...
# 3  photo  https://socialbuzz.cdn.com/content/storage/356...
# 4  video  https://socialbuzz.cdn.com/content/storage/01a...

# %%
concat_2= pd.concat([concat_1,df_content_cap],axis=1)
concat_2
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video
# ..                                    ...    ...
# 995  5b62e10e-3c19-4d28-a57c-e9bdc3d6758d  video
# 996  4fe420fa-a193-4408-bd5d-62a020233609    GIF
# ...

# %%
arrange_concat_2= concat_2[['Content ID', 'User ID', 'Type', "Category",'URL']]
arrange_concat_2.head(5)
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  8d3cd87d-8a31-4935-9a4f-b319bfe05f31
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  beb1f34e-7870-46d6-9fc7-2e12eb83ce43
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  a5c65404-5894-4b87-82f2-d787cbee86b4
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  9fb4ce88-fac1-406c-8544-1a899cee7aaf
# 4  01ab84dd-6364-4236-abbb-3f237db77180  e206e31b-5f85-4964-b6ea-d7ee5324def1
#
#     Type        Category                                                URL
# 0  photo        Studying  https://socialbuzz.cdn.com/content/storage/975...
# 1  photo  Healthy Eating  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  photo  Healthy Eating  https://socialbuzz.cdn.com/content/storage/230...
# 3  photo      Technology  https://socialbuzz.cdn.com/content/storage/356...
# 4  video            Food  https://socialbuzz.cdn.com/content/storage/01a...

# %%
checking_data_TYPE= arrange_concat_2.info()
checking_data_TYPE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  1000 non-null   object
#  1   User ID     1000 non-null   object
#  2   Type        1000 non-null   object
#  3   Category    1000 non-null   object
#  4   URL         801 non-null    object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
removing_content_colm= arrange_concat_2[['Content ID','Type', "Category"]]
removing_content_colm.head()
# Out:
#                              Content ID   Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  Healthy Eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  Healthy Eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6  photo      Technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180  video            Food

# %%
renaming_content_col= removing_content_colm.rename(columns={'Type':'Content Type', 'Category':'Content Category'})
renaming_content_col
# Out:
#                                Content ID Content Type Content Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2        photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo   Healthy Eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f        photo   Healthy Eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6        photo       Technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180        video             Food
# ..                                    ...          ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video  Public Speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF       Technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio         Veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF          Culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio       Technology
#
# [1000 rows x 3 columns]

# %%
# exporting_the_file= renaming_content_col.to_csv('New_Anu_Content_edit.csv')

# %% [markdown]
# ### Cleaning REACTION

# %%
df_reaction= pd.read_csv('Anu_Reactions.csv')
df_reaction
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type          Datetime
# 0                                       NaN         NaN  22-04-2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  07-11-2020 09:43
# ...

# %%
df_reaction_cap= df_reaction["Type"].str.title()
df_reaction_cap
# Out:
# 0               NaN
# 1           Disgust
# 2           Dislike
# 3            Scared
# 4           Disgust
#             ...
# 25548       Dislike
# 25549     Intrigued
# 25550    Interested
# 25551       Worried
# 25552       Cherish
# Name: Type, Length: 25553, dtype: object

# %%
reaction_concat_1= df_reaction[['Content ID', 'User ID', 'Datetime']]
reaction_concat_1
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID          Datetime
# 0                                       NaN  22-04-2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f  07-11-2020 09:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6  17-06-2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2  18-04-2021 05:13
# 4      34e8add9-0206-47fd-a501-037b994650a2  06-01-2021 19:13
# ...

# %%
reaction_concat_2= pd.concat([reaction_concat_1,df_reaction_cap], axis=1)
reaction_concat_2
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID          Datetime        Type
# 0                                       NaN  22-04-2021 15:17         NaN
# 1      5d454588-283d-459d-915d-c48a2cb4c27f  07-11-2020 09:43     Disgust
# 2      92b87fa5-f271-43e0-af66-84fac21052e6  17-06-2021 12:22     Dislike
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2  18-04-2021 05:13      Scared
# ...

# %%
arrange_reaction_concat_2= reaction_concat_2[['Content ID', 'User ID', 'Type','Datetime']]
arrange_reaction_concat_2
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type          Datetime
# 0                                       NaN         NaN  22-04-2021 15:17
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     Disgust  07-11-2020 09:43
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     Dislike  17-06-2021 12:22
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      Scared  18-04-2021 05:13
# ...

# %%
checking_Reation_dataType= arrange_reaction_concat_2.info()
checking_Reation_dataType
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Content ID  25553 non-null  object
#  1   User ID     22534 non-null  object
#  2   Type        24573 non-null  object
#  3   Datetime    25553 non-null  object
# dtypes: object(4)
# memory usage: 798.7+ KB

# %%
checking_Reation_NULL= arrange_reaction_concat_2.isnull().sum()
checking_Reation_NULL
# Out:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
Removing_REACTION_col= arrange_reaction_concat_2[['Content ID', 'Type']]
Removing_REACTION_col.head(5)
# Out:
#                              Content ID     Type
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2      NaN
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  Disgust
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  Dislike
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2   Scared
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Disgust

# %%
dropping_Reaction_NULL= Removing_REACTION_col.dropna(axis=0)
dropping_Reaction_NULL.tail(6)
# Out:
#                                  Content ID        Type
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56     Worried
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56     Dislike
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56   Intrigued
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56  Interested
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56     Worried
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56     Cherish

# %%
# exporting_reaction= dropping_Reaction_NULL.to_csv('New_Anu_Reaction_edit.csv')

# %% [markdown]
# ### Cleaning REACTION TYPE

# %%
df_reactionType= pd.read_csv('Anu_ReactionTypes.csv')
df_reactionType
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df_reactionType_cap_1= df_reactionType['Type'].str.capitalize()
df_reactionType_cap_1.head(3)
# Out:
# 0      Heart
# 1       Want
# 2    Disgust
# Name: Type, dtype: object

# %%
just_dataframe= df_reactionType['Score']
just_dataframe.head(3)
# Out:
# 0    60
# 1    70
# 2     0
# Name: Score, dtype: int64

# %%
concat_df_reactionType= pd.concat([df_reactionType_cap_1,just_dataframe],axis=1)
concat_df_reactionType
# Out:
#            Type  Score
# 0         Heart     60
# 1          Want     70
# 2       Disgust      0
# 3          Hate      5
# 4    Interested     30
# 5   Indifferent     20
# 6          Love     65
# 7    Super love     75
# 8       Cherish     70
# 9         Adore     72
# 10         Like     50
# 11      Dislike     10
# 12    Intrigued     45
# 13      Peeking     35
# 14       Scared     15
# 15      Worried     12

# %%
checking_ReactionType_datatype= concat_df_reactionType.info()
checking_ReactionType_datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Type    16 non-null     object
#  1   Score   16 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %%
# exporting_reactionType= concat_df_reactionType.to_csv('New_Anu_ReactionTypes_edit.csv')

# %% [markdown]
# # Merging Data:- Content ID, Category, Content Type, Reaction Type, and Reaction Score.

# %%
Merge_CONTENT= renaming_content_col
Merge_CONTENT.head(5)
# Out:
#                              Content ID Content Type Content Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo         Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo   Healthy Eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo   Healthy Eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo       Technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video             Food

# %%
Merge_CONTENT.isnull().sum()
# Out:
# Content ID          0
# Content Type        0
# Content Category    0
# dtype: int64

# %%
Merge_REACTION=dropping_Reaction_NULL
Merge_REACTION.head(5)
# Out:
#                              Content ID        Type
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust
# 5  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested

# %%
Merge_REACTION.isnull().sum()
# Out:
# Content ID    0
# Type          0
# dtype: int64

# %%
Merge_REACTION_Type= concat_df_reactionType
Merge_REACTION_Type
# Out:
#            Type  Score
# 0         Heart     60
# 1          Want     70
# 2       Disgust      0
# 3          Hate      5
# 4    Interested     30
# 5   Indifferent     20
# 6          Love     65
# 7    Super love     75
# 8       Cherish     70
# 9         Adore     72
# 10         Like     50
# 11      Dislike     10
# 12    Intrigued     45
# 13      Peeking     35
# 14       Scared     15
# 15      Worried     12

# %%
Merge_REACTION_Type.isnull().sum()
# Out:
# Type     0
# Score    0
# dtype: int64

# %%
merging_1= pd.merge(Merge_REACTION, Merge_CONTENT, on= 'Content ID', how= 'left')
merging_1.head()
# Out:
#                              Content ID        Type Content Type  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
#
#   Content Category
# 0         Studying
# 1         Studying
# 2         Studying
# 3         Studying
# 4         Studying

# %%
merging_1.isnull().sum()
# Out:
# Content ID          0
# Type                0
# Content Type        0
# Content Category    0
# dtype: int64

# %%
merging_2= pd.merge(merging_1, Merge_REACTION_Type, on ='Type', how= 'left' )
merging_2.head(5)
# Out:
#                              Content ID        Type Content Type  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
#
#   Content Category  Score
# 0         Studying    0.0
# 1         Studying   10.0
# 2         Studying   15.0
# 3         Studying    0.0
# 4         Studying   30.0

# %%
merging_2.isnull().sum()
# Out:
# Content ID             0
# Type                   0
# Content Type           0
# Content Category       0
# Score               1519
# dtype: int64

# %%
merging_2[merging_2['Type']=='Super Love']
# Out:
#                                  Content ID        Type Content Type  \
# 15     97522e57-d9ab-4bd6-97bf-c24d952602d2  Super Love        photo
# 28     97522e57-d9ab-4bd6-97bf-c24d952602d2  Super Love        photo
# 33     97522e57-d9ab-4bd6-97bf-c24d952602d2  Super Love        photo
# 35     97522e57-d9ab-4bd6-97bf-c24d952602d2  Super Love        photo
# 61     230c4e4d-70c3-461d-b42c-ec09396efb3f  Super Love        photo
# ...                                     ...         ...          ...
# 24479  435007a5-6261-4d8b-b0a4-55fdc189754b  Super Love        audio
# 24497  435007a5-6261-4d8b-b0a4-55fdc189754b  Super Love        audio
# 24501  435007a5-6261-4d8b-b0a4-55fdc189754b  Super Love        audio
# 24515  435007a5-6261-4d8b-b0a4-55fdc189754b  Super Love        audio
# 24551  4e4c9690-c013-4ee7-9e66-943d8cbd27b7  Super Love          GIF
#
#       Content Category  Score
# 15            Studying    NaN
# 28            Studying    NaN
# 33            Studying    NaN
# ...

# %%
merging_2.shape
# Out:
# (24573, 5)

# %%
filling_score= merging_2.fillna(75)
filling_score
# Out:
#                                  Content ID        Type Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
# ...                                     ...         ...          ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56     Dislike        audio
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56   Intrigued        audio
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56  Interested        audio
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56     Worried        audio
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56     Cherish        audio
#
#       Content Category  Score
# 0             Studying    0.0
# 1             Studying   10.0
# 2             Studying   15.0
# ...

# %%
filling_score['Score']= filling_score['Score'].astype(int)

# %%
filling_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24573 entries, 0 to 24572
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Content ID        24573 non-null  object
#  1   Type              24573 non-null  object
#  2   Content Type      24573 non-null  object
#  3   Content Category  24573 non-null  object
#  4   Score             24573 non-null  int32
# dtypes: int32(1), object(4)
# memory usage: 1.0+ MB

# %%
grouping= filling_score.groupby('Content Category')['Score'].sum()
grouping
# Out:
# Content Category
# Animals            74965
# Cooking            64756
# Culture            66579
# Dogs               52511
# Education          57436
# Fitness            55323
# Food               66676
# Healthy Eating     69339
# Public Speaking    49264
# Science            71168
# Soccer             57783
# Studying           54269
# Technology         68738
# Tennis             50339
# Travel             64880
# Veganism           49619
# Name: Score, dtype: int32

# %%
framing_all_cat= grouping.to_frame().reset_index()
framing_all_cat
# Out:
#    Content Category  Score
# 0           Animals  74965
# 1           Cooking  64756
# 2           Culture  66579
# 3              Dogs  52511
# 4         Education  57436
# 5           Fitness  55323
# 6              Food  66676
# 7    Healthy Eating  69339
# 8   Public Speaking  49264
# 9           Science  71168
# 10           Soccer  57783
# 11         Studying  54269
# 12       Technology  68738
# 13           Tennis  50339
# 14           Travel  64880
# 15         Veganism  49619

# %%
checking_top_5= grouping.nlargest(5)
checking_top_5
# Out:
# Content Category
# Animals           74965
# Science           71168
# Healthy Eating    69339
# Technology        68738
# Food              66676
# Name: Score, dtype: int32

# %%
framing_top5_cat= checking_top_5.to_frame().reset_index()
framing_top5_cat
# Out:
#   Content Category  Score
# 0          Animals  74965
# 1          Science  71168
# 2   Healthy Eating  69339
# 3       Technology  68738
# 4             Food  66676

# %%
# xport= filling_score.to_csv('Xport_merge.csv')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Adding few Columns

# %%
new_col= pd.read_csv('Just_Xporting.csv')
new_col.head(5)
# Out:
#    Unnamed: 0                            Content ID        Type Content Type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
#
#   Content Category  Score    Datetime  Post a day
# 0         Studying      0  22-04-2021           1
# 1         Studying     10  07-11-2020           1
# 2         Studying     15  17-06-2021           1
# 3         Studying      0  18-04-2021           1
# 4         Studying     30  06-01-2021           1

# %%
new_col['Datetime']= pd.to_datetime(new_col['Datetime'])
new_col.head(5)
# Out:
#    Unnamed: 0                            Content ID        Type Content Type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
#
#   Content Category  Score   Datetime  Post a day
# 0         Studying      0 2021-04-22           1
# 1         Studying     10 2020-07-11           1
# 2         Studying     15 2021-06-17           1
# 3         Studying      0 2021-04-18           1
# 4         Studying     30 2021-06-01           1

# %%
new_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24573 entries, 0 to 24572
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        24573 non-null  int64
#  1   Content ID        24573 non-null  object
#  2   Type              24573 non-null  object
#  3   Content Type      24573 non-null  object
#  4   Content Category  24573 non-null  object
#  5   Score             24573 non-null  int64
#  6   Datetime          24573 non-null  datetime64[ns]
#  7   Post a day        24573 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
new_col['Month']=new_col['Datetime'].dt.month
new_col
# Out:
#        Unnamed: 0                            Content ID        Type  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested
# ...           ...                                   ...         ...
# 24568       24568  75d6b589-7fae-4a6d-b0d0-752845150e56     Dislike
# 24569       24569  75d6b589-7fae-4a6d-b0d0-752845150e56   Intrigued
# 24570       24570  75d6b589-7fae-4a6d-b0d0-752845150e56  Interested
# 24571       24571  75d6b589-7fae-4a6d-b0d0-752845150e56     Worried
# 24572       24572  75d6b589-7fae-4a6d-b0d0-752845150e56     Cherish
#
#       Content Type Content Category  Score   Datetime  Post a day  Month
# 0            photo         Studying      0 2021-04-22           1      4
# ...

# %%
mains= new_col[['Content ID', 'Type', 'Content Type', 'Content Category', 'Score', 'Datetime', 'Month', "Post a day"]]
mains
# Out:
#                                  Content ID        Type Content Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     Dislike        photo
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2      Scared        photo
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2     Disgust        photo
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  Interested        photo
# ...                                     ...         ...          ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56     Dislike        audio
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56   Intrigued        audio
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56  Interested        audio
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56     Worried        audio
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56     Cherish        audio
#
#       Content Category  Score   Datetime  Month  Post a day
# 0             Studying      0 2021-04-22      4           1
# ...

# %%
mains_date_group= mains.groupby('Month')['Post a day'].sum()
mains_date_group
# Out:
# Month
# 1     2140
# 2     1876
# 3     1981
# 4     1988
# 5     2116
# 6     2073
# 7     2128
# 8     2070
# 9     1970
# 10    2097
# 11    2042
# 12    2092
# Name: Post a day, dtype: int64

# %%
date_group_frame= mains_date_group.to_frame().reset_index()
date_group_frame
# Out:
#     Month  Post a day
# 0       1        2140
# 1       2        1876
# 2       3        1981
# 3       4        1988
# 4       5        2116
# 5       6        2073
# 6       7        2128
# 7       8        2070
# 8       9        1970
# 9      10        2097
# 10     11        2042
# 11     12        2092

# %%
mains_date_group_large= mains_date_group.nlargest(5)
mains_date_group_large
# Out:
# Month
# 1     2140
# 7     2128
# 5     2116
# 10    2097
# 12    2092
# Name: Post a day, dtype: int64

# %%
top5_date_frame=mains_date_group_large.to_frame().reset_index()
top5_date_frame
# Out:
#    Month  Post a day
# 0      1        2140
# 1      7        2128
# 2      5        2116
# 3     10        2097
# 4     12        2092

# %%
top5_date_frame['Month']=top5_date_frame['Month'].astype(str)
top5_date_frame
# Out:
#   Month  Post a day
# 0     1        2140
# 1     7        2128
# 2     5        2116
# 3    10        2097
# 4    12        2092

# %%
top5_date_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       5 non-null      object
#  1   Post a day  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
mains_reaction_Category= mains.groupby('Content Category')['Post a day'].sum()
mains_reaction_Category
# Out:
# Content Category
# Animals            1897
# Cooking            1664
# Culture            1676
# Dogs               1338
# Education          1433
# Fitness            1395
# Food               1699
# Healthy Eating     1717
# Public Speaking    1217
# Science            1796
# Soccer             1457
# Studying           1363
# Technology         1698
# Tennis             1328
# Travel             1647
# Veganism           1248
# Name: Post a day, dtype: int64

# %%
framing_mains_reaction_Category= mains_reaction_Category.to_frame().reset_index()
framing_mains_reaction_Category
# Out:
#    Content Category  Post a day
# 0           Animals        1897
# 1           Cooking        1664
# 2           Culture        1676
# 3              Dogs        1338
# 4         Education        1433
# 5           Fitness        1395
# 6              Food        1699
# 7    Healthy Eating        1717
# 8   Public Speaking        1217
# 9           Science        1796
# 10           Soccer        1457
# 11         Studying        1363
# 12       Technology        1698
# 13           Tennis        1328
# 14           Travel        1647
# 15         Veganism        1248

# %%
mains_reaction_Category_large= mains_reaction_Category.nlargest(5)
mains_reaction_Category_large
# Out:
# Content Category
# Animals           1897
# Science           1796
# Healthy Eating    1717
# Food              1699
# Technology        1698
# Name: Post a day, dtype: int64

# %%
frameing_mains_reaction_Category_large= mains_reaction_Category_large.to_frame().reset_index()
frameing_mains_reaction_Category_large
# Out:
#   Content Category  Post a day
# 0          Animals        1897
# 1          Science        1796
# 2   Healthy Eating        1717
# 3             Food        1699
# 4       Technology        1698

# %% [markdown]
# #### Visualization

# %%
All_category= framing_all_cat.plot.bar()
All_category
# Out:
# <AxesSubplot:>

# %%
top_5_cat= framing_top5_cat.plot.bar()
top_5_cat
# Out:
# <AxesSubplot:>

# %%
months_high_upload= top5_date_frame.plot.bar()
months_high_upload
# Out:
# <AxesSubplot:>

# %%
category_most_reaction= mains_reaction_Category_large.plot.bar()

# %%
plt.figure(figsize=(8,8))
plt.title('Cetagories with most reactions')
plt.pie(x= framing_mains_reaction_Category['Post a day'], autopct='%.2f', labels= framing_mains_reaction_Category['Content Category'])
plt.show()
